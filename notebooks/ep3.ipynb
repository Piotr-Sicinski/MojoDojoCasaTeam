# %%
import matplotlib
from qiskit import *

qr = QuantumRegister(2)
cr = ClassicalRegister(2)

circut = QuantumCircuit(qr, cr)
circut.draw()
# Out:
#
# q1_0:
#
# q1_1:
#
# c1: 2/

# %%
# %matplotlib inline

# %%
circut.h(qr[0])
circut.draw(output='mpl')

# %%
circut.cx(qr[0], qr[1])
circut.draw(output='mpl')

# %%
circut.measure(qr, cr)
circut.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circut, backend=simulator).result()
result
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.12.2', qobj_id='', job_id='88a60ba4-6435-4997-a9e1-8026fa093edb', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x3': 521, '0x0': 503}), header=QobjExperimentHeader(creg_sizes=[['c1', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-121', qreg_sizes=[['q1', 2]], metadata={}), status=DONE, seed_simulator=2646228552, metadata={'parallel_state_update': 8, 'parallel_shots': 1, 'sample_measure_time': 0.00065975, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'device': 'CPU', 'active_input_qubits': [0, 1], 'measure_sampling': True, 'num_clbits': 2, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'fusion': {'enabled': False}}, time_taken=0.001609667)], date=2023-09-30T22:07:48.481826, status=COMPLETED, header=None, metadata={'mpi_rank': 0, 'num_mpi_processes': 1, 'num_processes_per_experiments': 1, 'max_gpu_memory_mb': 0, 'time_taken_execute': 0.001643875, 'max_memory_mb': 16384, 'parallel_experiments': 1, 'omp_enabled': True}, time_taken=0.002360105514526367)

# %%
from qiskit.tools.visualization import plot_histogram

plot_histogram(result.get_counts(circut))
